# %%
import os
import requests
import time
from bs4 import BeautifulSoup
from urllib.parse import urljoin
import random
import re

# %%
categories = {
    "Technology": ["https://spectrum.ieee.org/", "https://www.technologyreview.com/", "https://arstechnica.com"],
    "Science": ["https://www.newscientist.com/", "https://phys.org/", "https://www.nature.com"],
    "Health": ["https://www.mayoclinic.org/", "https://www.nih.gov/", "https://www.statnews.com/"],
    "Finance": ["https://www.ft.com/", "https://www.wsj.com/", "https://www.cnbc.com/"],
    "Sports": ["https://theathletic.com/", "https://www.si.com/", "https://sports.yahoo.com/"],
    "Education": ["https://www.insidehighered.com/", "https://www.chronicle.com/", "https://www.edweek.org"],
    "Entertainment": ["https://ew.com/", "https://deadline.com/", "https://www.rollingstone.com"],
    "Gaming": ["https://www.pcgamer.com/", "https://kotaku.com/", "https://www.eurogamer.net/"],
    "Politics": ["https://www.theatlantic.com/", "https://foreignpolicy.com/", "https://www.bbc.com/news/politics"],
    "Travel": ["https://www.travelandleisure.com/", "https://www.nationalgeographic.com/travel", "https://www.cntraveler.com"],
    "Food": ["https://www.eater.com/", "https://www.cooksillustrated.com/", "https://www.seriouseats.com"],
    "Fashion": ["https://wwd.com/", "https://www.thecut.com/", "https://www.gq.com"],
    "Business": ["https://fortune.com/", "https://www.fastcompany.com/", "https://www.economist.com"],
    "Environment": ["https://e360.yale.edu/", "https://grist.org/", "https://www.theguardian.com/environment"],
    "AI and Machine Learning": ["https://www.artificialintelligence-news.com", "https://indiaai.gov.in", "https://aimagazine.com"],
    "Automobiles": ["https://www.caranddriver.com/", "https://www.roadandtrack.com/", "https://www.autoblog.com"],
    "Cryptocurrency": ["https://decrypt.co/", "https://www.blockchainnews.com/", "https://www.cryptonews.com"],
    "History": ["https://www.worldhistory.org", "https://www.historyextra.com/", "https://www.britishmuseum.org/research/british-museum-publications"],
    "Startups": ["https://news.crunchbase.com/", "https://sifted.eu/", "https://www.startupgrind.com"],
    "Cybersecurity": ["https://www.wired.com/category/security/", "https://techcrunch.com/category/security/", "https://www.krebsonsecurity.com"]
}

# %%
output_dir = "text_dataset"
os.makedirs(output_dir, exist_ok=True)

def clean_text(text):
    """Clean and normalize extracted text."""
    text = re.sub(r'\s+', ' ', text)
    text = re.sub(r'[^\w\s.,!?-]', '', text)  
    return text.strip()

def extract_text(url):
    """Extract text content from a webpage and clean it."""
    try:
        headers = {"User-Agent": "Mozilla/5.0"}
        response = requests.get(url, headers=headers, timeout=10)
        response.raise_for_status()
        soup = BeautifulSoup(response.content, 'html.parser')
        text = ' '.join([p.get_text() for p in soup.find_all('p')])
        cleaned_text = clean_text(text)
        return cleaned_text if len(cleaned_text) > 250 else None  
    except Exception as e:
        print(f"Failed to fetch {url}: {e}")
        return None

def get_internal_links(base_url):
    """Fetch internal links from a given website."""
    try:
        headers = {"User-Agent": "Mozilla/5.0"}
        response = requests.get(base_url, headers=headers, timeout=10)
        response.raise_for_status()
        soup = BeautifulSoup(response.content, 'html.parser')
        links = set()
        for link in soup.find_all('a', href=True):
            full_url = urljoin(base_url, link['href'])
            if base_url in full_url:
                links.add(full_url)
        return list(links)[:5] 
    except Exception as e:
        print(f"Error fetching links from {base_url}: {e}")
        return []



for category, websites in categories.items():
    text_file_path = os.path.join(output_dir, f"{category}.txt")
    with open(text_file_path, 'w', encoding='utf-8') as f:
        for website in websites:
            links = get_internal_links(website)
            for link in links:
                print(f"Crawling: {link}")
                text = extract_text(link)
                if text:
                    f.write(text+'\n\n')
                time.sleep(random.uniform(1, 3)) 
    print(f"Completed {category}")


print("Text dataset collection completed!")
# Out:
# Crawling: https://spectrum.ieee.org/topic/climate-tech/
# Crawling: https://spectrum.ieee.org/type/explainer/
# Crawling: https://spectrum.ieee.org/topic/consumer-electronics/
# Crawling: https://spectrum.ieee.org/ukraine-rare-earth-minerals
# Crawling: https://spectrum.ieee.org/touchscreens
# Crawling: https://www.technologyreview.com/topic/artificial-intelligence/
# Crawling: https://www.technologyreview.com/2025/01/03/1108955/green-hydrogen-steel-greenhouse-gases-carbon-emissions-breakthrough-technologies-2025/
# Crawling: https://www.technologyreview.com/
# Crawling: https://www.technologyreview.com/2025/01/03/1108937/fast-learning-robots-generative-ai-breakthrough-technologies-2025/
# Crawling: https://www.technologyreview.com/mit-alumni-news-topics/1865/
# Crawling: https://arstechnica.com/science/2025/03/huh-the-valuable-role-of-interjections/
# Crawling: https://arstechnica.com/store/product/subscriptions/
# Crawling: https://arstechnica.com/science/2025/03/new-research-shows-bigger-animals-get-more-cancer-defying-decades-old-belief/
# Crawling: https://arstechnica.com/google/2025/03/doj-google-must-sell-chrome-android-could-be-next/
# Crawling: https://arstechnica.com/gadgets/2025/03/google-pixel-4as-painful-update-was-due-to-battery-overheating-risk/
# Completed Technology
# Crawling: https://www.newscientist.com/press-room/
# Crawling: https://www.newscientist.com/crosswords/
# Crawling: https://www.newscientist.com/terms/
# Crawling: https://www.newscientist.com/about/
# Crawling: https://www.newscientist.com/science-events/
# Crawling: https://phys.org/?deviceType=mobile
# Crawling: https://phys.org/news/2025-03-war-crimes-defendants-coverage-audiences.html
# Crawling: https://phys.org/sort/rank/1d/
# Crawling: https://phys.org/weekly-news/
# Crawling: https://phys.org/#nav-commented
# Crawling: https://www.nature.com/articles/s41586-025-08645-4
# Crawling: https://www.nature.com/info/legal-notice
# Crawling: https://www.nature.com/authors/index.html
# Crawling: https://www.nature.com/nature/for-referees
# Crawling: https://idp.nature.com/auth/personal/springernature?redirect_uri=https://www.nature.com/nature
# Completed Science
# Crawling: https://www.mayoclinic.org/symptoms
# Crawling: https://www.mayoclinic.org/diseases-conditions/sarcoma/care-at-mayo-clinic/mac-20351051
# Crawling: https://www.mayoclinic.org/patient-centered-care
# Crawling: https://www.mayoclinic.org/drugs-supplements
# Crawling: https://www.mayoclinic.org/diseases-conditions/index?letter=R
# Crawling: https://www.nih.gov/glance/nih-glance-labs.jpg
# Crawling: https://www.nih.gov/news-events/events
# Crawling: https://www.nih.gov/research-training/clinical-research-resources
# Crawling: https://www.nih.gov/institutes-nih/nih-institute-center-contact-information
# Crawling: https://www.nih.gov/about-nih/what-we-do/science-health-public-trust
# Crawling: https://www.statnews.com/privacy/
# Crawling: https://www.statnews.com/2025/03/10/beam-therapeutics-crispr-study-results/
# Crawling: https://www.statnews.com/privacy/ccpa-do-not-sell/
# Crawling: https://www.statnews.com/2025/03/05/nih-indirect-costs-lawsuit-federal-judge-extends-order-blocking-trump-cuts/
# Crawling: https://www.statnews.com/2025/01/20/trump-inauguration-health-care-policy-with-maha-robert-kennedy-boost/
# Completed Health
# Crawling: https://www.ft.com/newsletters
# Crawling: https://www.ft.com/content/68abaa41-bd3c-4413-8c87-8358b33ea805
# Crawling: https://www.ft.com/content/ee20978f-bbcd-4616-954c-7749dc5334fd
# Crawling: https://www.ft.com/content/203fffd7-95bb-4bb7-8a66-51407fa6ef3f
# Crawling: https://www.ft.com/content/a39c9c6a-cae0-4b6d-a94f-ef1e6583e4d8
# Error fetching links from https://www.wsj.com/: 401 Client Error: HTTP Forbidden for url: https://www.wsj.com/
# Crawling: https://www.cnbc.com/select/best-balance-transfer-credit-cards/
# Crawling: https://www.cnbc.com/select/checking-accounts-with-no-overdraft-fees/
# Crawling: https://www.cnbc.com/select/small-business/
# Crawling: https://www.cnbc.com/2025/02/25/hotels-that-provide-shoes-handbags-clothes-baby-and-pet-items-.html
# Crawling: https://www.cnbc.com/pro/news/
# Completed Finance
# Crawling: https://www.si.com/faq
# Crawling: https://www.si.com/college-football/college-football/north-carolina-ad-preferred-nfl-oc-before-bill-belichick-hire
# Crawling: https://www.si.com/mlb/mo-vaugh-admits-ped-hgh-use
# Crawling: https://www.si.com/author/ben-s-soccer
# Crawling: https://www.si.com/
# Crawling: https://sports.yahoo.com/college-basketball/news/
# Crawling: https://sports.yahoo.com/nba/denver-nuggets-oklahoma-city-thunder-2025031025/
# Crawling: https://sports.yahoo.com/college-basketball/rankings/
# Crawling: https://sports.yahoo.com/college-womens-basketball/standings/
# Crawling: https://sports.yahoo.com/soccer/ligue-1/
# Completed Sports
# Crawling: https://www.insidehighered.com/news/quick-takes/2025/03/10/adl-other-pro-israel-groups-condemn-aaup-palestine-webinar
# Crawling: https://www.insidehighered.com/news/faculty-issues/career-development
# Crawling: https://www.insidehighered.com/news/tech-innovation/administrative-tech
# Crawling: https://www.insidehighered.com/news/students/graduate-students-and-postdocs
# Crawling: https://www.insidehighered.com/news/government
# Error fetching links from https://www.chronicle.com/: 403 Client Error: Forbidden for url: https://www.chronicle.com/
# Crawling: https://www.edweek.org/about/our-organization
# Crawling: https://www.edweek.org/events/k-12-essentials-forum/learning-interventions-that-work
# Crawling: https://www.edweek.org/by/madeline-will
# Crawling: https://www.edweek.org/products/subscriptions
# Crawling: https://www.edweek.org/leadership/these-simple-classroom-exercises-can-improve-student-behavior/2025/02
# Completed Education
# Crawling: https://ew.com/1923-recap-season-2-duttons-survive-blizzard-alex-faces-worse-new-york-11693459
# Crawling: https://ew.com/genre/horror/
# Crawling: https://ew.com/law-and-order-famous-guest-stars-11693330
# Crawling: https://ew.com/harvey-weinstein-addresses-adrien-brody-oscars-speech-referencing-kids-11690224
# Crawling: https://ew.com/about-us-7966374#toc-diversity--inclusion
# Crawling: https://deadline.com/tag/visual-effects-and-screen/
# Crawling: https://deadline.com/2025/03/michelle-obama-craig-robinson-imo-podcast-sxsw-1236320358/
# Failed to fetch https://deadline.com/2025/03/michelle-obama-craig-robinson-imo-podcast-sxsw-1236320358/: HTTPSConnectionPool(host='deadline.com', port=443): Read timed out.
# Crawling: https://deadline.com/video/the-surrender-interview-sxsw-studio/
# Crawling: https://deadline.com/2025/03/bill-maher-anora-oscars-win-emilia-perez-cancel-culture-1236314806/
# Failed to fetch https://deadline.com/2025/03/bill-maher-anora-oscars-win-emilia-perez-cancel-culture-1236314806/: HTTPSConnectionPool(host='deadline.com', port=443): Read timed out.
# Crawling: https://deadline.com/2025/03/shout-studios-north-america-rights-thriller-pretty-thing-1236313970/
# Crawling: https://www.rollingstone.com/author/andy-greene/
# Crawling: https://www.rollingstone.com/t/creators/
# Failed to fetch https://www.rollingstone.com/t/creators/: ('Connection broken: IncompleteRead(477 bytes read, 3582 more expected)', IncompleteRead(477 bytes read, 3582 more expected))
# Crawling: https://www.rollingstone.com/tv-movies/tv-movie-recaps/white-lotus-season-3-episode-4-1235287976/
# Failed to fetch https://www.rollingstone.com/tv-movies/tv-movie-recaps/white-lotus-season-3-episode-4-1235287976/: HTTPSConnectionPool(host='www.rollingstone.com', port=443): Read timed out.
# Crawling: https://www.rollingstone.com/music/music-news/counting-crows-2025-tour-dates-gaslight-anthem-1235292764/
# Failed to fetch https://www.rollingstone.com/music/music-news/counting-crows-2025-tour-dates-gaslight-anthem-1235292764/: HTTPSConnectionPool(host='www.rollingstone.com', port=443): Read timed out.
# Crawling: https://www.rollingstone.com/t/artist-you-need-to-know/
# Failed to fetch https://www.rollingstone.com/t/artist-you-need-to-know/: ('Connection broken: IncompleteRead(1688 bytes read, 2154 more expected)', IncompleteRead(1688 bytes read, 2154 more expected))
# Completed Entertainment
# Error fetching links from https://www.pcgamer.com/: HTTPSConnectionPool(host='www.pcgamer.com', port=443): Read timed out.
# Error fetching links from https://kotaku.com/: HTTPSConnectionPool(host='kotaku.com', port=443): Read timed out. (read timeout=10)
# Error fetching links from https://www.eurogamer.net/: HTTPSConnectionPool(host='www.eurogamer.net', port=443): Read timed out.
# Completed Gaming
# Error fetching links from https://www.theatlantic.com/: HTTPSConnectionPool(host='www.theatlantic.com', port=443): Read timed out.
# Crawling: https://foreignpolicy.com/saved-articles/
# Crawling: https://foreignpolicy.com/
# Failed to fetch https://foreignpolicy.com/: HTTPSConnectionPool(host='foreignpolicy.com', port=443): Read timed out. (read timeout=10)
# Crawling: https://foreignpolicy.com/author/fabrice-deprez/
# Failed to fetch https://foreignpolicy.com/author/fabrice-deprez/: HTTPSConnectionPool(host='foreignpolicy.com', port=443): Read timed out. (read timeout=10)
# Crawling: https://foreignpolicy.com/reprint-permissions/
# Failed to fetch https://foreignpolicy.com/reprint-permissions/: HTTPSConnectionPool(host='foreignpolicy.com', port=443): Read timed out.
# Crawling: https://foreignpolicy.com/author/nils-gilman/
# Error fetching links from https://www.bbc.com/news/politics: HTTPSConnectionPool(host='www.bbc.com', port=443): Read timed out. (read timeout=10)
# Completed Politics
